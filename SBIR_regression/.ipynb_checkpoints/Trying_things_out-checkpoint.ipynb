# %%
import numpy as np
import json
from os import listdir
from os.path import isfile, join
import matplotlib as plt
from IPython.display import Image
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %%
import os

# %%
#gets all the names of all the image files that I want to print out
image_arrays = [f for f in listdir('test_images') if isfile(join('test_images', f)) and f.endswith(".jpg")]

# %%
len(image_arrays)
# Out:
# 115

# %%
for thing in image_arrays:
    display(Image(filename='test_images/{}'.format(thing)))

# %%
for thing in filepaths:
    display(Image(filename='{}'.format(thing)))

# %%
pwd
# Out:
# u'/root/SBIR_regression'

# %%
cd ..
# Out:
# /root

# %%
ls
# Out:
# SBIR_regression/

# %%
cd ..
# Out:
# /

# %%
ls
# Out:
# bin/   dev/  home/  lib64/  mnt/  proc/  run/   srv/  tmp/  var/
# boot/  etc/  lib/   media/  opt/  root/  sbin/  sys/  usr/

# %%
cd SBIR_regression
# Out:
# [Errno 2] No such file or directory: 'SBIR_regression'
# /bin

# %%
ls

# %%
cd ..
# Out:
# /

# %%
cd bin
# Out:
# /bin

# %%
ls
# Out:
# bin/   dev/  home/  lib64/  mnt/  proc/  run/   srv/  tmp/  var/
# boot/  etc/  lib/   media/  opt/  root/  sbin/  sys/  usr/

# %%
cd root
# Out:
# /root

# %%
ls
# Out:
# SBIR_regression/

# %%
cd SBIR_regression
# Out:
# /root/SBIR_regression

# %%
ls
# Out:
# LICENSE
# Nearest_Neighbors.ipynb
# Nearest_neighbors_clean.ipynb
# README.md
# Trying_things_out.ipynb
# bwmorph.py
# bwmorph.pyc
# caffe_utils/
# class_utils.py*
# class_utils.pyc
# feat.npy
# func_utils.py
# getfeat_img.py
# getfeat_img2.ipynb
# getfeat_skt.py
# getfeat_skt2.ipynb
# lampshades_images/
# model/
# samples/
# test_images/
# test_sketches/
# testing_images_and_sketch_vectors.pkl
# triplet1_InceptionV1_InceptionV1_halfshare_inception4e_ld256_triplet_sketchy_iter_31200.caffemodel

# %%
#prints out all the names in the current directory
names=[name for name in os.listdir(".") if os.path.isdir(name)]

# %%
cd il
# Out:
# /root/SBIR_regression/lampshades_images/lampshades/il

# %%
names=[name for name in os.listdir(".") if os.path.isdir(name)]

# %%
names
# Out:
# ['6fd2db',
#  'f7d704',
#  'cefd48',
#  '79dab8',
#  'cbfb0e',
#  '44f194',
#  '1cd565',
#  'bf4041',
#  'd2cff0',
#  'b19a6b',
#  'aca784',
#  '9992c8',
#  '99bfc8',
#  '240b9a',
#  '9dc331',
#  'bd5409',
#  'eaf7a0',
#  '39795b',
#  '404fed',
#  'e18f61',
#  '3ca0e3',
#  '77481f',
#  '27898a',
#  'f1d65d',
#  'fa139e',
#  '11e878',
#  '84bd70',
#  '6354dc',
#  '7df402',
#  '29a9a7',
#  'cfa078',
#  'be4a94',
#  '8dddcd',
#  '5c4b6a',
#  'ec46ff',
#  '522b5e',
#  'afb213',
#  '7fe351',
#  '8bf693',
#  '369797',
#  '71c5b5',
#  'af372f',
#  'f00f3e',
#  '070fd3',
#  '0e34ea',
#  'd8c233',
#  '582c10',
#  'd052b7',
#  '80d685',
#  '6323af',
#  'fb99bb',
#  '3d48da',
#  'e8d468',
#  'ff1aa0',
#  '4738a3',
#  '446d7a',
#  '24adb5',
#  'd88b73',
#  '089d5e',
#  '651341',
#  'f5fcd0',
#  'f70112',
#  'ed7cf3',
#  'c5696c',
#  'fa4afd',
#  '3b1cdb',
#  '61b7b0',
#  '43c77e',
#  '4f2d88',
#  'f7fa83',
#  '1298fd',
#  'a96869',
#  '37f563',
#  '3c2477',
#  '66b284',
#  '7dcf35',
# ...

# %%
#prints out all the filepaths for the images
filepaths = []
for subdir, dirs, files in os.walk(u'/root/SBIR_regression/lampshades_images/lampshades/il'):
    for filename in files:
        filepath = subdir + os.sep + filename

        if filepath.endswith(".jpg") or filepath.endswith(".png"):
            print (filepath)
            filepaths.append(filepath)
# Out:
# /root/SBIR_regression/lampshades_images/lampshades/il/6fd2db/283719187/il_fullxfull.283719187.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/f7d704/2227853759/il_fullxfull.2227853759_oas7.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/cefd48/1669595857/il_fullxfull.1669595857_1ztd.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/79dab8/1409507543/il_fullxfull.1409507543_cxzs.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/cbfb0e/1848612580/il_fullxfull.1848612580_hws9.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/44f194/1682307532/il_fullxfull.1682307532_89s7.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/1cd565/2417475808/il_fullxfull.2417475808_1wwq.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/bf4041/741722189/il_fullxfull.741722189_ddvl.jpg
# /root/SBIR_regression/lampshades_images/lampshades/il/d2cff0/1592919944/il_fullxfull.1592919944_mwzt.jpg
# ...

# %%
len(filepaths)
# Out:
# 2189

# %%
pwd
# Out:
# u'/root/SBIR_regression/lampshades_images/lampshades/il'

# %%
for root, dirs, files in os.walk(top, topdown=False):
    for name in dirs:
        print os.path.join(root, name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-abd4157111fd> in <module>()
# ----> 1 for root, dirs, files in os.walk(top, topdown=False):
#       2     for name in dirs:
#       3         print os.path.join(root, name)
#
# NameError: name 'top' is not defined

# %%
folder=[name for name in os.listdir(".") if os.path.isdir(name)]

# %%
cd 6fd2db
# Out:
# /root/SBIR_regression/lampshades_images/lampshades/il/6fd2db

# %%
ls
# Out:
# 283719187/

# %%
ls
# Out:
# 283719187/

# %%
cd 283719187
# Out:
# /root/SBIR_regression/lampshades_images/lampshades/il/6fd2db/283719187

# %%
ls
# Out:
# il_fullxfull.283719187.jpg

# %%
#gets all the names of all the image files that I want to print out
image_arrays = [f for f in listdir('lampshades_images/lampshades') if isfile(join('lampshades_images/lampshades', f))]

# %%
image_arrays
# Out:
# []

# %%
cd lampshades_images
# Out:
# /root/SBIR_regression/lampshades_images

# %%
cd lampshades_images
# Out:
# /root/SBIR_regression/lampshades_images

# %%
ls
# Out:
# lampshades/

# %%
cd lampshades
# Out:
# /root/SBIR_regression/lampshades_images/lampshades

# %%
ls
# Out:
# il/

# %%
cd il
# Out:
# /root/SBIR_regression/lampshades_images/lampshades/il

# %%
ls
# Out:
# 001ce3/  1e1dd5/  3bb603/  5641ac/  6ebdbf/  8bbe19/  aacae5/  c80c65/  e54957/
# 0024db/  1e6164/  3bcc18/  564330/  6f0c98/  8bf693/  aaded4/  c825b2/  e55248/
# 00551f/  1e7f27/  3bdb73/  5661c2/  6f1b09/  8c0091/  aaea34/  c83d96/  e56190/
# 007aeb/  1e81c4/  3c0119/  566237/  6f3f85/  8c10fd/  ab15ac/  c86b3f/  e58f31/
# 009382/  1e8243/  3c20ac/  56721a/  6f96bd/  8c1632/  ab24cc/  c87b12/  e5d6d1/
# 009d78/  1eb7ce/  3c2477/  568c02/  6f9983/  8c30ee/  ab6418/  c87d7d/  e5f786/
# 00b03a/  1ee1fa/  3c4548/  56be98/  6f9f42/  8c4e76/  ab65ff/  c8a1f1/  e621a5/
# 00c356/  1f0a4b/  3c9ba1/  56bf2a/  6fb625/  8c6735/  ab6874/  c8b978/  e6411b/
# 00fdad/  1f0f23/  3ca0e3/  56bf75/  6fba68/  8c7228/  ab6d23/  c914d5/  e643d4/
# 0111a1/  1f17e1/  3ca574/  56cb9c/  6fd289/  8cb56c/  ab76c8/  c9657f/  e67f6c/
# 014966/  1f1f37/  3cb224/  56de14/  6fd2db/  8cc3db/  ab8b1f/  c96c39/  e68817/
# 01640e/  1fa67b/  3cb9f3/  5707d7/  6ff776/  8ce07d/  ab9732/  c98971/  e6960d/
# ...

# %%
names=[name for name in os.listdir(".") if os.path.isdir(name)]

# %%
names
# Out:
# ['il']
